# %% [markdown]
# Cecilia: BERT + LIAR
#
# Gabrielle: INLP

# %% [markdown]
# Plan:
#
# 1) How BERT works
# 2) Fine tune
# 3) Debias
#
# Detailed plan:
#
# (https://course.fast.ai/)
#
# (https://huggingface.co/learn/llm-course/chapter1/1)

# %% [markdown]
# Why BERT:
#
# Good for large datasets
# Easy to understand
