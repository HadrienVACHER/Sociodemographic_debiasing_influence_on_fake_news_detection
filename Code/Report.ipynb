# %% [markdown]
# Cecilia: BERT + LIAR
#
# Gabrielle: INLP

# %% [markdown]
# Plan:
#
# 1) How BERT works
# 2) Fine tune
# 3) Debias
#
# Detailed plan:
#
# (https://course.fast.ai/)
#
# (https://huggingface.co/learn/llm-course/chapter1/1)
#
# 1) https://course.fast.ai/Lessons/lesson3.html : Neural net foundations
#
# 2) C:\...\Stat_App\Bibliography\Secondary\ADAM.pdf : Optimizer ADAM
#
# 3) https://course.fast.ai/Lessons/lesson4.html : Natural Language (NLP)
#
# 4) https://huggingface.co/learn/llm-course/chapter1/1 : Transformer models
#
# 5) C:\...\Stat'App\Stat_App\Bibliography\Secondary\ATTENTION.pdf : Attention is all you need
#
# 6) C:\...\Stat'App\Stat_App\Bibliography\Primary\BERT.pdf : BERT
#
# 7) https://huggingface.co/learn/llm-course/chapter2/1 : Using transformers
#
# 8) https://huggingface.co/learn/llm-course/chapter3/1 : Fine-tuning a pretrained model
#
# 9) C:\...\Stat'App\Stat_App\Bibliography\Primary\LIAR.pdf : LIAR
#
# 10) C:\...\Stat'App\Stat_App\Bibliography\Primary\INLP.pdf : Debiasing techniques

# %% [markdown]
# Why BERT:
#
# Good for large datasets
# Easy to understand
